# %%
import numpy as np
import pandas as pd
#import sklearn as sk
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
#from pandas.plotting import scatter_matrix

# %%
data = pd.read_csv('suicideRate.csv')
data.head(10)
# Out:
#            place  pop2022  growthRate          area country cca3  cca2  \
# 426    2305825.0  0.01068       30355       Lesotho     LSO   LS   426
# 328     808726.0  0.00517      214969        Guyana     GUY   GY   328
# 748    1201670.0  0.00788       17364      Eswatini     SWZ   SZ   748
# 410   51815810.0 -0.00028      100210   South Korea     KOR   KR   410
# 296     131232.0  0.01830         811      Kiribati     KIR   KI   296
# 583     114164.0  0.00913         702    Micronesia     FSM   FM   583
# 440    2750055.0 -0.01313       65300     Lithuania     LTU   LT   440
# 740     618040.0  0.00825      163820      Suriname     SUR   SR   740
# 643  144713314.0 -0.00268    17098242        Russia     RUS   RU   643
# 710   59893885.0  0.00845     1221037  South Africa     ZAF   ZA   710
#
#               ccn3           region           subregion  ...    density  \
# 426         Africa  Southern Africa  Sub-Saharan Africa  ...    75.9494
# ...

# %%
rows = len(data.axes[0])
cols = len(data.axes[1])
print("Total number of rows is", rows)
print("Total number of columns is", cols)
# Out:
# Total number of rows is 179
# Total number of columns is 21

# %%
data.dtypes
# Out:
# place             float64
# pop2022           float64
# growthRate          int64
# area               object
# country            object
# cca3               object
# cca2                int64
# ccn3               object
# region             object
# subregion          object
# landAreaKm        float64
# density           float64
# densityMi         float64
# Rank              float64
# rate2019male      float64
# rate2019female    float64
# rate2019both      float64
# rate2015male        int64
# rate2015female      int64
# rate2015both        int64
# rank              float64
# dtype: object

# %%
plt.figure(figsize=(10, 4))
newDataX = data['rate2019both']
newDataY = data['ccn3']
sns.countplot(y=data['ccn3'])
plt.xlabel('Suicide Rates of Males and Females in 2019')
plt.ylabel('Per Continent')
plt.show()

# %%
pd.
# Out:
#   File "<ipython-input-6-bc888235687a>", line 1
#     pd.
#        ^
# SyntaxError: invalid syntax

# %%
pd.
